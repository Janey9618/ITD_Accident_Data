# %%
pip install pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from pandas) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
print ("hello lord")
# Out:
# hello lord

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (2.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from matplotlib) (4.55.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from matplotlib) (2.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\lab4-studentpc38\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
birds = pd.read_csv('Datasets//penguins.csv')

# %%
birds
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# 2                195.0       3250.0  female  2007
# 3                  NaN          NaN     NaN  2007
# 4                193.0       3450.0  female  2007
# ..                 ...          ...     ...   ...
# 339              207.0       4000.0    male  2009
# 340              202.0       3400.0  female  2009
# 341              193.0       3775.0    male  2009
# 342              210.0       4100.0    male  2009
# 343              198.0       3775.0  female  2009
#
# [344 rows x 9 columns]

# %% [markdown]
# <h1> CHECKING THE DATA FRAME INFORMATION AND DESCRIPTIVE ANALYTICS</h1>

# %%
birds.info
# Out:
# <bound method DataFrame.info of      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# 2                195.0       3250.0  female  2007
# 3                  NaN          NaN     NaN  2007
# 4                193.0       3450.0  female  2007
# ..                 ...          ...     ...   ...
# 339              207.0       4000.0    male  2009
# 340              202.0       3400.0  female  2009
# 341              193.0       3775.0    male  2009
# 342              210.0       4100.0    male  2009
# 343              198.0       3775.0  female  2009
#
# [344 rows x 9 columns]>

# %%
birds.describe
# Out:
# <bound method NDFrame.describe of      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# 2                195.0       3250.0  female  2007
# 3                  NaN          NaN     NaN  2007
# 4                193.0       3450.0  female  2007
# ..                 ...          ...     ...   ...
# 339              207.0       4000.0    male  2009
# 340              202.0       3400.0  female  2009
# 341              193.0       3775.0    male  2009
# 342              210.0       4100.0    male  2009
# 343              198.0       3775.0  female  2009
#
# [344 rows x 9 columns]>

# %%
birds.describe().T
# Out:
#                    count         mean         std     min       25%      50%  \
# rowid              344.0   172.500000   99.448479     1.0    86.750   172.50
# bill_length_mm     342.0    43.921930    5.459584    32.1    39.225    44.45
# bill_depth_mm      342.0    17.151170    1.974793    13.1    15.600    17.30
# flipper_length_mm  342.0   200.915205   14.061714   172.0   190.000   197.00
# body_mass_g        342.0  4201.754386  801.954536  2700.0  3550.000  4050.00
# year               344.0  2008.029070    0.818356  2007.0  2007.000  2008.00
#
#                        75%     max
# rowid               258.25   344.0
# bill_length_mm       48.50    59.6
# bill_depth_mm        18.70    21.5
# flipper_length_mm   213.00   231.0
# body_mass_g        4750.00  6300.0
# year               2009.00  2009.0

# %%
birds['body_mass_g']
# Out:
# 0      3750.0
# 1      3800.0
# 2      3250.0
# 3         NaN
# 4      3450.0
#         ...
# 339    4000.0
# 340    3400.0
# 341    3775.0
# 342    4100.0
# 343    3775.0
# Name: body_mass_g, Length: 344, dtype: float64

# %% [markdown]
# <h1>FILTERING DATA BASED FROM COLUMNS</h1>

# %%
birds['species']
# Out:
# 0         Adelie
# 1         Adelie
# 2         Adelie
# 3         Adelie
# 4         Adelie
#          ...
# 339    Chinstrap
# 340    Chinstrap
# 341    Chinstrap
# 342    Chinstrap
# 343    Chinstrap
# Name: species, Length: 344, dtype: object

# %%
birds['species'].values
# Out:
# array(['Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap'], dtype=object)

# %% [markdown]
# <h1>CREATING NEW COLUMNS</h1>

# %%
birds['weight'] = np.round(birds['body_mass_g'] /1000 , 2)

# %%
birds
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 0                181.0       3750.0    male  2007    3.75
# 1                186.0       3800.0  female  2007    3.80
# 2                195.0       3250.0  female  2007    3.25
# 3                  NaN          NaN     NaN  2007     NaN
# 4                193.0       3450.0  female  2007    3.45
# ..                 ...          ...     ...   ...     ...
# 339              207.0       4000.0    male  2009    4.00
# 340              202.0       3400.0  female  2009    3.40
# 341              193.0       3775.0    male  2009    3.78
# 342              210.0       4100.0    male  2009    4.10
# 343              198.0       3775.0  female  2009    3.78
#
# [344 rows x 10 columns]

# %%
birds['weight_kilo'] = birds ['body_mass_g'] /1000

# %%
birds
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year  weight  weight_kilo
# 0                181.0       3750.0    male  2007    3.75        3.750
# 1                186.0       3800.0  female  2007    3.80        3.800
# 2                195.0       3250.0  female  2007    3.25        3.250
# 3                  NaN          NaN     NaN  2007     NaN          NaN
# 4                193.0       3450.0  female  2007    3.45        3.450
# ..                 ...          ...     ...   ...     ...          ...
# 339              207.0       4000.0    male  2009    4.00        4.000
# 340              202.0       3400.0  female  2009    3.40        3.400
# 341              193.0       3775.0    male  2009    3.78        3.775
# 342              210.0       4100.0    male  2009    4.10        4.100
# 343              198.0       3775.0  female  2009    3.78        3.775
#
# [344 rows x 11 columns]

# %%
birds.drop(columns = 'weight_kilo')
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 0                181.0       3750.0    male  2007    3.75
# 1                186.0       3800.0  female  2007    3.80
# 2                195.0       3250.0  female  2007    3.25
# 3                  NaN          NaN     NaN  2007     NaN
# 4                193.0       3450.0  female  2007    3.45
# ..                 ...          ...     ...   ...     ...
# 339              207.0       4000.0    male  2009    4.00
# 340              202.0       3400.0  female  2009    3.40
# 341              193.0       3775.0    male  2009    3.78
# 342              210.0       4100.0    male  2009    4.10
# 343              198.0       3775.0  female  2009    3.78
#
# [344 rows x 10 columns]

# %% [markdown]
# <h1> CHECKING FOR NULL VALUES</h1>

# %%
birds.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# weight                2
# weight_kilo           2
# dtype: int64

# %%
birds['body_mass_g'].mean()
# Out:
# np.float64(4201.754385964912)

# %%
birds['sex'].mode()
# Out:
# 0    male
# Name: sex, dtype: object

# %% [markdown]
#   <h1>  WHAT TO DO WITH NULL VALUES</h1>

# %%
 birds['bill_length_mm'].mean()
# Out:
# np.float64(43.9219298245614)

# %%
 birds['bill_length_mm'].median()
# Out:
# np.float64(44.45)

# %%
 birds['bill_length_mm'].mode()
# Out:
# 0    41.1
# Name: bill_length_mm, dtype: float64

# %%
 birds['bill_length_mm'] = birds ['bill_length_mm'].fillna(birds['bill_length_mm'].mean())

# %%
birds.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# weight                2
# weight_kilo           2
# dtype: int64

# %%
birds['sex'].mode()
# Out:
# 0    male
# Name: sex, dtype: object

# %%
birds['sex'] = birds['sex'].fillna(birds['sex'].mode()[0])

# %%
birds.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        2
# flipper_length_mm    2
# body_mass_g          2
# sex                  0
# year                 0
# weight               2
# weight_kilo          2
# dtype: int64

# %%
birds['bill_depth_mm'] = birds['bill_depth_mm'].fillna(birds['bill_depth_mm'].mode()[0])

# %%
birds.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    2
# body_mass_g          2
# sex                  0
# year                 0
# weight               2
# weight_kilo          2
# dtype: int64

# %%
birds['flipper_length_mm'] = birds['flipper_length_mm'].fillna(birds['flipper_length_mm'].mode()[0])

# %%
birds.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          2
# sex                  0
# year                 0
# weight               2
# weight_kilo          2
# dtype: int64

# %%
birds['body_mass_g'] = birds['body_mass_g'].fillna(birds['body_mass_g'].mode()[0])

# %%
birds.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# weight               2
# weight_kilo          2
# dtype: int64

# %%
birds['weight'] = birds['weight'].fillna(birds['weight'].mode()[0])

# %%
birds.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# weight               0
# weight_kilo          2
# dtype: int64

# %%
birds['weight_kilo'] = birds['weight_kilo'].fillna(birds['weight_kilo'].mode()[0])

# %%
birds.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# weight               0
# weight_kilo          0
# dtype: int64

# %%
birds['year'] = birds['year'].astype('category')

# %%
birds['species'] =birds ['species'].astype('category')

# %%
birds['sex'] =birds ['sex'].astype('category')

# %%
birds['island'] =birds ['island'].astype('category')

# %%
birds['rowid'] =birds ['rowid'].astype('category')

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    category
#  1   species            344 non-null    category
#  2   island             344 non-null    category
#  3   bill_length_mm     344 non-null    float64
#  4   bill_depth_mm      344 non-null    float64
#  5   flipper_length_mm  344 non-null    float64
#  6   body_mass_g        344 non-null    float64
#  7   sex                344 non-null    category
#  8   year               344 non-null    category
#  9   weight             344 non-null    float64
#  10  weight_kilo        344 non-null    float64
# dtypes: category(5), float64(6)
# memory usage: 29.6 KB

# %%
birds.head(25)
# Out:
#    rowid species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      1  Adelie  Torgersen        39.10000           18.7              181.0
# 1      2  Adelie  Torgersen        39.50000           17.4              186.0
# 2      3  Adelie  Torgersen        40.30000           18.0              195.0
# 3      4  Adelie  Torgersen        43.92193           17.0              190.0
# 4      5  Adelie  Torgersen        36.70000           19.3              193.0
# 5      6  Adelie  Torgersen        39.30000           20.6              190.0
# 6      7  Adelie  Torgersen        38.90000           17.8              181.0
# 7      8  Adelie  Torgersen        39.20000           19.6              195.0
# 8      9  Adelie  Torgersen        34.10000           18.1              193.0
# 9     10  Adelie  Torgersen        42.00000           20.2              190.0
# 10    11  Adelie  Torgersen        37.80000           17.1              186.0
# 11    12  Adelie  Torgersen        37.80000           17.3              180.0
# 12    13  Adelie  Torgersen        41.10000           17.6              182.0
# 13    14  Adelie  Torgersen        38.60000           21.2              191.0
# 14    15  Adelie  Torgersen        34.60000           21.1              198.0
# 15    16  Adelie  Torgersen        36.60000           17.8              185.0
# 16    17  Adelie  Torgersen        38.70000           19.0              195.0
# 17    18  Adelie  Torgersen        42.50000           20.7              197.0
# 18    19  Adelie  Torgersen        34.40000           18.4              184.0
# 19    20  Adelie  Torgersen        46.00000           21.5              194.0
# 20    21  Adelie     Biscoe        37.80000           18.3              174.0
# 21    22  Adelie     Biscoe        37.70000           18.7              180.0
# 22    23  Adelie     Biscoe        35.90000           19.2              189.0
# 23    24  Adelie     Biscoe        38.20000           18.1              185.0
# 24    25  Adelie     Biscoe        38.80000           17.2              180.0
#
#     body_mass_g     sex  year  weight  weight_kilo
# 0        3750.0    male  2007    3.75        3.750
# 1        3800.0  female  2007    3.80        3.800
# 2        3250.0  female  2007    3.25        3.250
# 3        3800.0    male  2007    3.80        3.800
# 4        3450.0  female  2007    3.45        3.450
# 5        3650.0    male  2007    3.65        3.650
# 6        3625.0  female  2007    3.62        3.625
# 7        4675.0    male  2007    4.68        4.675
# 8        3475.0    male  2007    3.48        3.475
# 9        4250.0    male  2007    4.25        4.250
# 10       3300.0    male  2007    3.30        3.300
# 11       3700.0    male  2007    3.70        3.700
# 12       3200.0  female  2007    3.20        3.200
# 13       3800.0    male  2007    3.80        3.800
# 14       4400.0    male  2007    4.40        4.400
# 15       3700.0  female  2007    3.70        3.700
# 16       3450.0  female  2007    3.45        3.450
# 17       4500.0    male  2007    4.50        4.500
# 18       3325.0  female  2007    3.32        3.325
# 19       4200.0    male  2007    4.20        4.200
# 20       3400.0  female  2007    3.40        3.400
# 21       3600.0    male  2007    3.60        3.600
# 22       3800.0  female  2007    3.80        3.800
# 23       3950.0    male  2007    3.95        3.950
# 24       3800.0    male  2007    3.80        3.800

# %%
birds.tail(15)
# Out:
#     rowid    species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 329   330  Chinstrap  Dream            50.7           19.7              203.0
# 330   331  Chinstrap  Dream            42.5           17.3              187.0
# 331   332  Chinstrap  Dream            52.2           18.8              197.0
# 332   333  Chinstrap  Dream            45.2           16.6              191.0
# 333   334  Chinstrap  Dream            49.3           19.9              203.0
# 334   335  Chinstrap  Dream            50.2           18.8              202.0
# 335   336  Chinstrap  Dream            45.6           19.4              194.0
# 336   337  Chinstrap  Dream            51.9           19.5              206.0
# 337   338  Chinstrap  Dream            46.8           16.5              189.0
# 338   339  Chinstrap  Dream            45.7           17.0              195.0
# 339   340  Chinstrap  Dream            55.8           19.8              207.0
# 340   341  Chinstrap  Dream            43.5           18.1              202.0
# 341   342  Chinstrap  Dream            49.6           18.2              193.0
# 342   343  Chinstrap  Dream            50.8           19.0              210.0
# 343   344  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year  weight  weight_kilo
# 329       4050.0    male  2009    4.05        4.050
# 330       3350.0  female  2009    3.35        3.350
# 331       3450.0    male  2009    3.45        3.450
# 332       3250.0  female  2009    3.25        3.250
# 333       4050.0    male  2009    4.05        4.050
# 334       3800.0    male  2009    3.80        3.800
# 335       3525.0  female  2009    3.52        3.525
# 336       3950.0    male  2009    3.95        3.950
# 337       3650.0  female  2009    3.65        3.650
# 338       3650.0  female  2009    3.65        3.650
# 339       4000.0    male  2009    4.00        4.000
# 340       3400.0  female  2009    3.40        3.400
# 341       3775.0    male  2009    3.78        3.775
# 342       4100.0    male  2009    4.10        4.100
# 343       3775.0  female  2009    3.78        3.775

# %%
birds['species']== "Chinstrap"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340     True
# 341     True
# 342     True
# 343     True
# Name: species, Length: 344, dtype: bool

# %%
birds[birds['species']== "Chinstrap"].count()
# Out:
# rowid                68
# species              68
# island               68
# bill_length_mm       68
# bill_depth_mm        68
# flipper_length_mm    68
# body_mass_g          68
# sex                  68
# year                 68
# weight               68
# weight_kilo          68
# dtype: int64

# %%
birds['species']== "Gentoo"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %%
birds[birds['species']== "Gentoo"].count()
# Out:
# rowid                124
# species              124
# island               124
# bill_length_mm       124
# bill_depth_mm        124
# flipper_length_mm    124
# body_mass_g          124
# sex                  124
# year                 124
# weight               124
# weight_kilo          124
# dtype: int64

# %%
birds['species']== "Adelie"
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %%
birds[birds['species']== "Adelie"].count()
# Out:
# rowid                152
# species              152
# island               152
# bill_length_mm       152
# bill_depth_mm        152
# flipper_length_mm    152
# body_mass_g          152
# sex                  152
# year                 152
# weight               152
# weight_kilo          152
# dtype: int64
